# %%
import pandas as pd 
import matplotlib.pyplot as plt 

table = pd.DataFrame({ 
    "Model": ["Linear","Random Forest","SVM"], 
    "Performance": ["Medium","High","Medium"], 
    "Selected": ["No","Yes","No"] 
})
table
# Out:
#            Model Performance Selected
# 0         Linear      Medium       No
# 1  Random Forest        High      Yes
# 2            SVM      Medium       No

# %%
table.to_csv('/kaggle/working/table_rq7.csv', index=False)
print("table")
# Out:
# table

# %%
plt.figure() 
plt.pie([1,2,1], labels=["Linear","RF","SVM"], autopct='%1.1f%%') 
plt.title("Final Model Selection") 
plt.savefig('/kaggle/working/figure_rq7.pdf') 
plt.show()
